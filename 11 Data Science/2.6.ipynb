# %%
# %conda install pymongo
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\paul\AppData\anaconda3\envs\g4g-ds
#
#   added / updated specs:
#     - pymongo
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cryptography-44.0.1        |  py313hbd6ee87_0         1.4 MB
#     dnspython-2.4.2            |  py313haa95532_0         467 KB
#     pymongo-4.8.0              |  py313h827c3e9_0         1.2 MB
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   cryptography       pkgs/main/win-64::cryptography-44.0.1-py313hbd6ee87_0
#   dnspython          pkgs/main/win-64::dnspython-2.4.2-py313haa95532_0
#   pymongo            pkgs/main/win-64::pymongo-4.8.0-py313h827c3e9_0
#
#
#
# Downloading and Extracting Packages
#
# cryptography-44.0.1  | 1.4 MB    |            |   0%
#
# pymongo-4.8.0        | 1.2 MB    |            |   0%
#
#
# dnspython-2.4.2      | 467 KB    |            |   0%
# cryptography-44.0.1  | 1.4 MB    | 1          |   1%
#
#
# dnspython-2.4.2      | 467 KB    | 3          |   3%
#
# pymongo-4.8.0        | 1.2 MB    | 1          |   1%
# cryptography-44.0.1  | 1.4 MB    | 3          |   3%
#
#
# dnspython-2.4.2      | 467 KB    | ##         |  21%
#
# pymongo-4.8.0        | 1.2 MB    | 7          |   8%
# cryptography-44.0.1  | 1.4 MB    | 8          |   9%
#
#
# dnspython-2.4.2      | 467 KB    | ###7       |  38%
# cryptography-44.0.1  | 1.4 MB    | #6         |  17%
#
#
# dnspython-2.4.2      | 467 KB    | #####4     |  55%
#
#
# dnspython-2.4.2      | 467 KB    | #########2 |  92%
# cryptography-44.0.1  | 1.4 MB    | ##7        |  28%
#
# pymongo-4.8.0        | 1.2 MB    | #4         |  14%
# cryptography-44.0.1  | 1.4 MB    | ####3      |  43%
#
# pymongo-4.8.0        | 1.2 MB    | ##4        |  25%
# cryptography-44.0.1  | 1.4 MB    | ######8    |  68%
# cryptography-44.0.1  | 1.4 MB    | ########9  |  89%
#
# pymongo-4.8.0        | 1.2 MB    | ###1       |  31%
#
# pymongo-4.8.0        | 1.2 MB    | ####       |  40%
#
# pymongo-4.8.0        | 1.2 MB    | #####1     |  52%
#
# pymongo-4.8.0        | 1.2 MB    | ######2    |  62%
#
# pymongo-4.8.0        | 1.2 MB    | #######2   |  73%
#
# pymongo-4.8.0        | 1.2 MB    | ########   |  80%
#
# pymongo-4.8.0        | 1.2 MB    | #########2 |  92%
#
# pymongo-4.8.0        | 1.2 MB    | ########## | 100%
#
#
# dnspython-2.4.2      | 467 KB    | ########## | 100%
# cryptography-44.0.1  | 1.4 MB    | ########## | 100%
#
# pymongo-4.8.0        | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/win-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/win-64/current_repodata.json HTTP/1.1" 304 0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.2
#   latest version: 25.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.3.1
#
#
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/cryptography-44.0.1-py313hbd6ee87_0.conda HTTP/1.1" 200 1485672
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/dnspython-2.4.2-py313haa95532_0.conda HTTP/1.1" 200 478552
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/pymongo-4.8.0-py313h827c3e9_0.conda HTTP/1.1" 200 1264361

# %%
from pymongo import MongoClient

# %%
client = MongoClient("localhost", 27017)

# %%
local_db = client.local

# %%
startup_log = local_db.startup_log

# %%
cursor = startup_log.find()

# %%
list_cur = list(cursor)
list_cur
# Out:
# [{'_id': 'DESKTOP-2UKQIVL-1697200141703',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2023, 10, 13, 12, 29, 1),
#   'startTimeLocal': 'Fri Oct 13 07:29:01.703',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 4432,
#   'buildinfo': {'version': '7.0.2',
#    'gitVersion': '02b3c655e1302209ef046da6ba3ef6749dd0b62a',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 2, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1697200306291',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2023, 10, 13, 12, 31, 46),
#   'startTimeLocal': 'Fri Oct 13 07:31:46.291',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 4960,
#   'buildinfo': {'version': '7.0.2',
#    'gitVersion': '02b3c655e1302209ef046da6ba3ef6749dd0b62a',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 2, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1698860741309',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2023, 11, 1, 17, 45, 41),
#   'startTimeLocal': 'Wed Nov  1 12:45:41.309',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5488,
#   'buildinfo': {'version': '7.0.2',
#    'gitVersion': '02b3c655e1302209ef046da6ba3ef6749dd0b62a',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 2, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1699014845992',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2023, 11, 3, 12, 34, 5),
#   'startTimeLocal': 'Fri Nov  3 07:34:05.992',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5436,
#   'buildinfo': {'version': '7.0.2',
#    'gitVersion': '02b3c655e1302209ef046da6ba3ef6749dd0b62a',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 2, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1699830570195',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2023, 11, 12, 23, 9, 30),
#   'startTimeLocal': 'Sun Nov 12 17:09:30.195',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5496,
#   'buildinfo': {'version': '7.0.2',
#    'gitVersion': '02b3c655e1302209ef046da6ba3ef6749dd0b62a',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 2, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1699845859596',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2023, 11, 13, 3, 24, 19),
#   'startTimeLocal': 'Sun Nov 12 21:24:19.596',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5496,
#   'buildinfo': {'version': '7.0.2',
#    'gitVersion': '02b3c655e1302209ef046da6ba3ef6749dd0b62a',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 2, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1699846141712',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2023, 11, 13, 3, 29, 1),
#   'startTimeLocal': 'Sun Nov 12 21:29:01.712',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5352,
#   'buildinfo': {'version': '7.0.2',
#    'gitVersion': '02b3c655e1302209ef046da6ba3ef6749dd0b62a',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 2, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1699848653230',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2023, 11, 13, 4, 10, 53),
#   'startTimeLocal': 'Sun Nov 12 22:10:53.230',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5392,
#   'buildinfo': {'version': '7.0.2',
#    'gitVersion': '02b3c655e1302209ef046da6ba3ef6749dd0b62a',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 2, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1699849527496',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2023, 11, 13, 4, 25, 27),
#   'startTimeLocal': 'Sun Nov 12 22:25:27.496',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5896,
#   'buildinfo': {'version': '7.0.2',
#    'gitVersion': '02b3c655e1302209ef046da6ba3ef6749dd0b62a',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 2, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1700552335655',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2023, 11, 21, 7, 38, 55),
#   'startTimeLocal': 'Tue Nov 21 01:38:55.655',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5344,
#   'buildinfo': {'version': '7.0.2',
#    'gitVersion': '02b3c655e1302209ef046da6ba3ef6749dd0b62a',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 2, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1700792790308',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2023, 11, 24, 2, 26, 30),
#   'startTimeLocal': 'Thu Nov 23 20:26:30.308',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5312,
#   'buildinfo': {'version': '7.0.2',
#    'gitVersion': '02b3c655e1302209ef046da6ba3ef6749dd0b62a',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 2, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1705341755555',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2024, 1, 15, 18, 2, 35),
#   'startTimeLocal': 'Mon Jan 15 12:02:35.555',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 39532,
#   'buildinfo': {'version': '7.0.5',
#    'gitVersion': '7809d71e84e314b497f282ea8aa06d7ded3eb205',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 5, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1707433186134',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2024, 2, 8, 22, 59, 46),
#   'startTimeLocal': 'Thu Feb  8 16:59:46.134',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5568,
#   'buildinfo': {'version': '7.0.5',
#    'gitVersion': '7809d71e84e314b497f282ea8aa06d7ded3eb205',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 5, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1707435233211',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2024, 2, 8, 23, 33, 53),
#   'startTimeLocal': 'Thu Feb  8 17:33:53.211',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5708,
#   'buildinfo': {'version': '7.0.5',
#    'gitVersion': '7809d71e84e314b497f282ea8aa06d7ded3eb205',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 5, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1708373711886',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2024, 2, 19, 20, 15, 11),
#   'startTimeLocal': 'Mon Feb 19 14:15:11.886',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5160,
#   'buildinfo': {'version': '7.0.5',
#    'gitVersion': '7809d71e84e314b497f282ea8aa06d7ded3eb205',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 5, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1711822421908',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2024, 3, 30, 18, 13, 41),
#   'startTimeLocal': 'Sat Mar 30 13:13:41.908',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 6012,
#   'buildinfo': {'version': '7.0.5',
#    'gitVersion': '7809d71e84e314b497f282ea8aa06d7ded3eb205',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 5, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1711822671541',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2024, 3, 30, 18, 17, 51),
#   'startTimeLocal': 'Sat Mar 30 13:17:51.541',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 6072,
#   'buildinfo': {'version': '7.0.5',
#    'gitVersion': '7809d71e84e314b497f282ea8aa06d7ded3eb205',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 5, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1718229520722',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2024, 6, 12, 21, 58, 40),
#   'startTimeLocal': 'Wed Jun 12 16:58:40.722',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5896,
#   'buildinfo': {'version': '7.0.5',
#    'gitVersion': '7809d71e84e314b497f282ea8aa06d7ded3eb205',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 5, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1720986336908',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2024, 7, 14, 19, 45, 36),
#   'startTimeLocal': 'Sun Jul 14 14:45:36.908',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5464,
#   'buildinfo': {'version': '7.0.5',
#    'gitVersion': '7809d71e84e314b497f282ea8aa06d7ded3eb205',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 5, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1720986612135',
#   'hostname': 'DESKTOP-2UKQIVL',
# ...
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1737243229790',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2025, 1, 18, 23, 33, 49),
#   'startTimeLocal': 'Sat Jan 18 17:33:49.790',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5356,
#   'buildinfo': {'version': '7.0.5',
#    'gitVersion': '7809d71e84e314b497f282ea8aa06d7ded3eb205',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 5, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1737243388191',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2025, 1, 18, 23, 36, 28),
#   'startTimeLocal': 'Sat Jan 18 17:36:28.191',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5644,
#   'buildinfo': {'version': '7.0.5',
#    'gitVersion': '7809d71e84e314b497f282ea8aa06d7ded3eb205',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 5, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1737510496462',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2025, 1, 22, 1, 48, 16),
#   'startTimeLocal': 'Tue Jan 21 19:48:16.462',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5684,
#   'buildinfo': {'version': '7.0.5',
#    'gitVersion': '7809d71e84e314b497f282ea8aa06d7ded3eb205',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 5, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1740608610139',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2025, 2, 26, 22, 23, 30),
#   'startTimeLocal': 'Wed Feb 26 16:23:30.139',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5760,
#   'buildinfo': {'version': '7.0.5',
#    'gitVersion': '7809d71e84e314b497f282ea8aa06d7ded3eb205',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 5, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1740698506236',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2025, 2, 27, 23, 21, 46),
#   'startTimeLocal': 'Thu Feb 27 17:21:46.236',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 6112,
#   'buildinfo': {'version': '7.0.5',
#    'gitVersion': '7809d71e84e314b497f282ea8aa06d7ded3eb205',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 5, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}},
#  {'_id': 'DESKTOP-2UKQIVL-1742243805594',
#   'hostname': 'DESKTOP-2UKQIVL',
#   'startTime': datetime.datetime(2025, 3, 17, 20, 36, 45),
#   'startTimeLocal': 'Mon Mar 17 15:36:45.594',
#   'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\7.0\\bin\\mongod.cfg',
#    'net': {'bindIp': '127.0.0.1', 'port': 27017},
#    'service': True,
#    'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\7.0\\data'},
#    'systemLog': {'destination': 'file',
#     'logAppend': True,
#     'path': 'C:\\Program Files\\MongoDB\\Server\\7.0\\log\\mongod.log'}},
#   'pid': 5428,
#   'buildinfo': {'version': '7.0.5',
#    'gitVersion': '7809d71e84e314b497f282ea8aa06d7ded3eb205',
#    'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#    'modules': [],
#    'allocator': 'tcmalloc',
#    'javascriptEngine': 'mozjs',
#    'sysInfo': 'deprecated',
#    'versionArray': [7, 0, 5, 0],
#    'openssl': {'running': 'Windows SChannel'},
#    'buildEnvironment': {'distmod': 'windows',
#     'distarch': 'x86_64',
#     'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline',
#     'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64',
#     'cxxflags': '/TP',
#     'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#     'target_arch': 'x86_64',
#     'target_os': 'windows',
#     'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC NDEBUG BOOST_ALL_NO_LIB _UNICODE UNICODE _SILENCE_CXX17_ALLOCATOR_VOID_DEPRECATION_WARNING _SILENCE_CXX17_OLD_ALLOCATOR_MEMBERS_DEPRECATION_WARNING _SILENCE_CXX17_CODECVT_HEADER_DEPRECATION_WARNING _SILENCE_ALL_CXX20_DEPRECATION_WARNINGS _CONSOLE _CRT_SECURE_NO_WARNINGS _ENABLE_EXTENDED_ALIGNED_STORAGE _SCL_SECURE_NO_WARNINGS _WIN32_WINNT 0x0A00 BOOST_USE_WINAPI_VERSION 0x0A00 NTDDI_VERSION 0x0A000000 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'},
#    'bits': 64,
#    'debug': False,
#    'maxBsonObjectSize': 16777216,
#    'storageEngines': ['devnull', 'wiredTiger']}}]

# %%
from pandas import DataFrame

# %%
DataFrame(list_cur)
# Out:
#                               _id  ...                                          buildinfo
# 0   DESKTOP-2UKQIVL-1697200141703  ...  {'version': '7.0.2', 'gitVersion': '02b3c655e1...
# 1   DESKTOP-2UKQIVL-1697200306291  ...  {'version': '7.0.2', 'gitVersion': '02b3c655e1...
# 2   DESKTOP-2UKQIVL-1698860741309  ...  {'version': '7.0.2', 'gitVersion': '02b3c655e1...
# 3   DESKTOP-2UKQIVL-1699014845992  ...  {'version': '7.0.2', 'gitVersion': '02b3c655e1...
# 4   DESKTOP-2UKQIVL-1699830570195  ...  {'version': '7.0.2', 'gitVersion': '02b3c655e1...
# 5   DESKTOP-2UKQIVL-1699845859596  ...  {'version': '7.0.2', 'gitVersion': '02b3c655e1...
# 6   DESKTOP-2UKQIVL-1699846141712  ...  {'version': '7.0.2', 'gitVersion': '02b3c655e1...
# 7   DESKTOP-2UKQIVL-1699848653230  ...  {'version': '7.0.2', 'gitVersion': '02b3c655e1...
# 8   DESKTOP-2UKQIVL-1699849527496  ...  {'version': '7.0.2', 'gitVersion': '02b3c655e1...
# 9   DESKTOP-2UKQIVL-1700552335655  ...  {'version': '7.0.2', 'gitVersion': '02b3c655e1...
# 10  DESKTOP-2UKQIVL-1700792790308  ...  {'version': '7.0.2', 'gitVersion': '02b3c655e1...
# 11  DESKTOP-2UKQIVL-1705341755555  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 12  DESKTOP-2UKQIVL-1707433186134  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 13  DESKTOP-2UKQIVL-1707435233211  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 14  DESKTOP-2UKQIVL-1708373711886  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 15  DESKTOP-2UKQIVL-1711822421908  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 16  DESKTOP-2UKQIVL-1711822671541  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 17  DESKTOP-2UKQIVL-1718229520722  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 18  DESKTOP-2UKQIVL-1720986336908  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 19  DESKTOP-2UKQIVL-1720986612135  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 20  DESKTOP-2UKQIVL-1721826480821  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 21  DESKTOP-2UKQIVL-1721826545913  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 22  DESKTOP-2UKQIVL-1723304468078  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 23  DESKTOP-2UKQIVL-1730762200343  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 24  DESKTOP-2UKQIVL-1730762339910  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 25  DESKTOP-2UKQIVL-1730862647856  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 26  DESKTOP-2UKQIVL-1732851144730  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 27  DESKTOP-2UKQIVL-1733002594359  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 28  DESKTOP-2UKQIVL-1733002785643  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 29  DESKTOP-2UKQIVL-1735062855489  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 30  DESKTOP-2UKQIVL-1735062974450  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 31  DESKTOP-2UKQIVL-1735674309132  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 32  DESKTOP-2UKQIVL-1735697612114  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 33  DESKTOP-2UKQIVL-1735839350679  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 34  DESKTOP-2UKQIVL-1735839675817  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 35  DESKTOP-2UKQIVL-1735845532012  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 36  DESKTOP-2UKQIVL-1736043299770  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 37  DESKTOP-2UKQIVL-1736555111136  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 38  DESKTOP-2UKQIVL-1736629554266  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 39  DESKTOP-2UKQIVL-1737243054593  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 40  DESKTOP-2UKQIVL-1737243229790  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 41  DESKTOP-2UKQIVL-1737243388191  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 42  DESKTOP-2UKQIVL-1737510496462  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 43  DESKTOP-2UKQIVL-1740608610139  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 44  DESKTOP-2UKQIVL-1740698506236  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
# 45  DESKTOP-2UKQIVL-1742243805594  ...  {'version': '7.0.5', 'gitVersion': '7809d71e84...
#
# [46 rows x 7 columns]
