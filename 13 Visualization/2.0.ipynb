# %%
# %pip install ipyvolume ipython_genutils
# %jupyter nbextension enable --py --sys-prefix ipyvolume
# %jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# Collecting ipyvolume
#   Using cached ipyvolume-0.6.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting ipywidgets>=7.0.0 (from ipyvolume)
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Collecting bqplot (from ipyvolume)
#   Using cached bqplot-0.13.1-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting numpy (from ipyvolume)
#   Downloading numpy-2.4.6-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting traittypes (from ipyvolume)
#   Using cached traittypes-0.2.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: traitlets in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from ipyvolume) (5.15.0)
# Collecting Pillow (from ipyvolume)
#   Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Collecting ipywebrtc (from ipyvolume)
#   Using cached ipywebrtc-0.6.0-py2.py3-none-any.whl.metadata (825 bytes)
# Collecting requests (from ipyvolume)
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting ipyvuetify (from ipyvolume)
#   Using cached ipyvuetify-1.11.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Collecting ipyvue>=1.7.0 (from ipyvolume)
#   Using cached ipyvue-1.12.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting pythreejs>=2.4.0 (from ipyvolume)
#   Using cached pythreejs-2.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting matplotlib (from ipyvolume)
#   Downloading matplotlib-3.10.9-cp313-cp313-win_amd64.whl.metadata (52 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from ipywidgets>=7.0.0->ipyvolume) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from ipywidgets>=7.0.0->ipyvolume) (9.14.0)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets>=7.0.0->ipyvolume)
#   Using cached widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets>=7.0.0->ipyvolume)
#   Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: colorama>=0.4.4 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (3.0.52)
# Requirement already satisfied: psutil>=7 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.6.3)
# Requirement already satisfied: wcwidth in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.8.7)
# Collecting ipydatawidgets>=1.1.1 (from pythreejs>=2.4.0->ipyvolume)
#   Using cached ipydatawidgets-4.3.5-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: executing>=1.2.0 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (3.0.1)
# Requirement already satisfied: pure-eval in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.2.3)
# Collecting pandas>=1.0.0 (from bqplot->ipyvolume)
#   Downloading pandas-3.0.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting bqscales<0.4,>=0.3.3 (from bqplot->ipyvolume)
#   Using cached bqscales-0.3.7-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from pandas>=1.0.0->bqplot->ipyvolume) (2.9.0.post0)
# Collecting tzdata (from pandas>=1.0.0->bqplot->ipyvolume)
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->bqplot->ipyvolume) (1.17.0)
# Collecting contourpy>=1.0.1 (from matplotlib->ipyvolume)
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->ipyvolume)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->ipyvolume)
#   Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->ipyvolume)
#   Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages (from matplotlib->ipyvolume) (26.2)
# Collecting pyparsing>=3 (from matplotlib->ipyvolume)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting charset_normalizer<4,>=2 (from requests->ipyvolume)
#   Downloading charset_normalizer-3.4.7-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting idna<4,>=2.5 (from requests->ipyvolume)
#   Using cached idna-3.17-py3-none-any.whl.metadata (6.4 kB)
# Collecting urllib3<3,>=1.26 (from requests->ipyvolume)
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests->ipyvolume)
#   Using cached certifi-2026.5.20-py3-none-any.whl.metadata (2.5 kB)
# Using cached ipyvolume-0.6.3-py3-none-any.whl (1.6 MB)
# Using cached ipyvue-1.12.0-py2.py3-none-any.whl (2.7 MB)
# Using cached ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
# Using cached widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
# Using cached pythreejs-2.4.2-py3-none-any.whl (3.4 MB)
# Using cached ipydatawidgets-4.3.5-py2.py3-none-any.whl (271 kB)
# Using cached traittypes-0.2.3-py2.py3-none-any.whl (8.1 kB)
# Using cached bqplot-0.13.1-py2.py3-none-any.whl (935 kB)
# Using cached bqscales-0.3.7-py3-none-any.whl (516 kB)
# Downloading numpy-2.4.6-cp313-cp313-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 12.3/12.3 MB 82.2 MB/s  0:00:00
# Downloading pandas-3.0.3-cp313-cp313-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 9.8/9.8 MB 127.5 MB/s  0:00:00
# Using cached ipyvuetify-1.11.3-py2.py3-none-any.whl (6.3 MB)
# Using cached ipywebrtc-0.6.0-py2.py3-none-any.whl (260 kB)
# Downloading matplotlib-3.10.9-cp313-cp313-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 8.2/8.2 MB 123.9 MB/s  0:00:00
# Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 78.4 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ---------------------------------------- 7.1/7.1 MB 121.3 MB/s  0:00:00
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Downloading charset_normalizer-3.4.7-cp313-cp313-win_amd64.whl (158 kB)
# Using cached idna-3.17-py3-none-any.whl (65 kB)
# Using cached urllib3-2.7.0-py3-none-any.whl (131 kB)
# Using cached certifi-2026.5.20-py3-none-any.whl (134 kB)
# Using cached tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Installing collected packages: ipywebrtc, widgetsnbextension, urllib3, tzdata, traittypes, pyparsing, Pillow, numpy, kiwisolver, jupyterlab_widgets, idna, fonttools, cycler, charset_normalizer, certifi, requests, pandas, contourpy, matplotlib, ipywidgets, ipyvue, ipydatawidgets, bqscales, pythreejs, ipyvuetify, bqplot, ipyvolume
#
#    -- -------------------------------------  2/27 [urllib3]
#    -- -------------------------------------  2/27 [urllib3]
#    -- -------------------------------------  2/27 [urllib3]
#    ---- -----------------------------------  3/27 [tzdata]
#    ---- -----------------------------------  3/27 [tzdata]
#    ------- --------------------------------  5/27 [pyparsing]
#    ------- --------------------------------  5/27 [pyparsing]
#    -------- -------------------------------  6/27 [Pillow]
#    -------- -------------------------------  6/27 [Pillow]
#    -------- -------------------------------  6/27 [Pillow]
#    -------- -------------------------------  6/27 [Pillow]
#    -------- -------------------------------  6/27 [Pillow]
#    -------- -------------------------------  6/27 [Pillow]
#    -------- -------------------------------  6/27 [Pillow]
#    -------- -------------------------------  6/27 [Pillow]
#    -------- -------------------------------  6/27 [Pillow]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ---------- -----------------------------  7/27 [numpy]
#    ------------- --------------------------  9/27 [jupyterlab_widgets]
#    -------------- ------------------------- 10/27 [idna]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ---------------- ----------------------- 11/27 [fonttools]
#    ------------------- -------------------- 13/27 [charset_normalizer]
#    ------------------- -------------------- 13/27 [charset_normalizer]
#    ---------------------- ----------------- 15/27 [requests]
#    ---------------------- ----------------- 15/27 [requests]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ----------------------- ---------------- 16/27 [pandas]
#    ------------------------- -------------- 17/27 [contourpy]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    ---------------------------- ----------- 19/27 [ipywidgets]
#    ---------------------------- ----------- 19/27 [ipywidgets]
#    ---------------------------- ----------- 19/27 [ipywidgets]
#    ---------------------------- ----------- 19/27 [ipywidgets]
#    ---------------------------- ----------- 19/27 [ipywidgets]
#    ----------------------------- ---------- 20/27 [ipyvue]
#    ------------------------------- -------- 21/27 [ipydatawidgets]
#    ------------------------------- -------- 21/27 [ipydatawidgets]
#    -------------------------------- ------- 22/27 [bqscales]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ---------------------------------- ----- 23/27 [pythreejs]
#    ----------------------------------- ---- 24/27 [ipyvuetify]
#    ----------------------------------- ---- 24/27 [ipyvuetify]
#    ----------------------------------- ---- 24/27 [ipyvuetify]
#    ----------------------------------- ---- 24/27 [ipyvuetify]
#    ----------------------------------- ---- 24/27 [ipyvuetify]
#    ----------------------------------- ---- 24/27 [ipyvuetify]
#    ----------------------------------- ---- 24/27 [ipyvuetify]
#    ----------------------------------- ---- 24/27 [ipyvuetify]
#    ----------------------------------- ---- 24/27 [ipyvuetify]
#    ----------------------------------- ---- 24/27 [ipyvuetify]
#    ----------------------------------- ---- 24/27 [ipyvuetify]
#    ----------------------------------- ---- 24/27 [ipyvuetify]
#    ----------------------------------- ---- 24/27 [ipyvuetify]
#    ------------------------------------- -- 25/27 [bqplot]
#    ------------------------------------- -- 25/27 [bqplot]
#    -------------------------------------- - 26/27 [ipyvolume]
#    -------------------------------------- - 26/27 [ipyvolume]
#    ---------------------------------------- 27/27 [ipyvolume]
#
# Successfully installed Pillow-12.2.0 bqplot-0.13.1 bqscales-0.3.7 certifi-2026.5.20 charset_normalizer-3.4.7 contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 idna-3.17 ipydatawidgets-4.3.5 ipyvolume-0.6.3 ipyvue-1.12.0 ipyvuetify-1.11.3 ipywebrtc-0.6.0 ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 kiwisolver-1.5.0 matplotlib-3.10.9 numpy-2.4.6 pandas-3.0.3 pyparsing-3.3.2 pythreejs-2.4.2 requests-2.34.2 traittypes-0.2.3 tzdata-2026.2 urllib3-2.7.0 widgetsnbextension-4.0.15
# Note: you may need to restart the kernel to use updated packages.
# UsageError: Line magic function `%jupyter` not found.

# %%
import numpy as np
import ipyvolume as ipv

V = np.zeros((128, 128, 128))  # our 3d array
# outer box
V[30:-30, 30:-30, 30:-30] = 0.75
V[35:-35, 35:-35, 35:-35] = 0.0
# inner box
V[50:-50, 50:-50, 50:-50] = 0.25
V[55:-55, 55:-55, 55:-55] = 0.0
ipv.quickvolshow(
    V, level=[0.25, 0.75], opacity=0.03, level_width=0.1, data_min=0, data_max=1
)
# Out:
# c:\Users\paul\programming\courses\python-exercises\.venv\Lib\site-packages\ipyvolume\serialize.py:102: RuntimeWarning: invalid value encountered in cast
#   subdata[..., i] = ((gradient[i][zindex] / 2.0 + 0.5) * 255).astype(np.uint8)
# Container(children=[VBox(children=(HBox(children=(Label(value='levels:'), FloatSlider(value=0.25, max=1.0, ste…

# %%
import ipyvolume as ipv
import numpy as np

x, y, z = np.random.random((3, 10000))
ipv.quickscatter(x, y, z, size=1, marker="sphere")
# Out:
# Container(figure=Figure(box_center=[0.5, 0.5, 0.5], box_size=[1.0, 1.0, 1.0], camera=PerspectiveCamera(fov=45.…

# %%
import ipyvolume as ipv
import numpy as np

x, y, z, u, v, w = np.random.random((6, 1000)) * 2 - 1
ipv.quickquiver(x, y, z, u, v, w, size=5)
# Out:
# Container(figure=Figure(box_center=[0.5, 0.5, 0.5], box_size=[1.0, 1.0, 1.0], camera=PerspectiveCamera(fov=45.…

# %%
import ipyvolume as ipv

x, y, z, u, v = ipv.examples.klein_bottle(draw=False)
ipv.figure()
m = ipv.plot_mesh(x, y, z, wireframe=False)
ipv.squarelim()
ipv.show()
# Out:
# Container(figure=Figure(box_center=[0.5, 0.5, 0.5], box_size=[1.0, 1.0, 1.0], camera=PerspectiveCamera(fov=45.…

# %%
import ipyvolume as ipv
import numpy as np

x, y, z, u, v, w = np.random.random((6, 1000)) * 2 - 1
selected = np.random.randint(0, 1000, 100)
ipv.figure()
quiver = ipv.quiver(x, y, z, u, v, w, size=5, size_selected=8, selected=selected)

from ipywidgets import FloatSlider, ColorPicker, VBox, jslink

size = FloatSlider(min=0, max=30, step=0.1)
size_selected = FloatSlider(min=0, max=30, step=0.1)
color = ColorPicker()
color_selected = ColorPicker()
jslink((quiver, "size"), (size, "value"))
jslink((quiver, "size_selected"), (size_selected, "value"))
jslink((quiver, "color"), (color, "value"))
jslink((quiver, "color_selected"), (color_selected, "value"))
VBox([ipv.gcc(), size, size_selected, color, color_selected])
# Out:
# VBox(children=(Container(figure=Figure(box_center=[0.5, 0.5, 0.5], box_size=[1.0, 1.0, 1.0], camera=Perspectiv…
